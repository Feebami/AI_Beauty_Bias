# %% [markdown]
# # Imports

# %%
import pandas as pd
import os
import numpy as np

# %% [markdown]
# # Load raw data

# %%
raw_df = pd.read_csv('generic_scores_all_2022.csv')
raw_df
# Out:
#           mean                                    image  \
# 0     1.117647        kuma-kum-GKbPbR0ZAT4-unsplash.jpg
# 1     1.000000             pexels-cottonbro-5529905.jpg
# 2     1.000000         pexels-nishant-aneja-2561432.jpg
# 3     1.428571                   woman-1929550_1920.jpg
# 4     1.500000          pexels-himesh-mehta-3059930.jpg
# ...        ...                                      ...
# 2602  9.000000                pexels-pixabay-247322.jpg
# 2603  9.375000                   women-5930352_1920.jpg
# 2604  9.222222  francesca-zama-1fhl_kmbfAE-unsplash.jpg
# 2605  9.625000           sofia--LNdco1UgNY-unsplash.jpg
# 2606  9.333333          pexels-mart¿¬-pardo-1674318.jpg
#
#                                                    path  malecm39  femalecf41  \
# 0     /home/ubuntu/ME-beautydatabase/images/female/c...       NaN         NaN
# 1     /home/ubuntu/ME-beautydatabase/images/male/asi...       NaN         NaN
# 2     /home/ubuntu/ME-beautydatabase/images/male/ind...       NaN         NaN
# 3                                                   NaN       1.0         1.0
# 4     /home/ubuntu/ME-beautydatabase/images/female/i...       NaN         NaN
# ...                                                 ...       ...         ...
# 2602  /home/ubuntu/ME-beautydatabase/images/female/c...       NaN         NaN
# 2603  /home/ubuntu/ME-beautydatabase/images/female/a...       NaN         NaN
# 2604  /home/ubuntu/ME-beautydatabase/images/female/h...       NaN         NaN
# 2605  /home/ubuntu/ME-beautydatabase/images/female/c...       NaN         NaN
# 2606  /home/ubuntu/ME-beautydatabase/images/male/cau...       NaN         NaN
#
#       femaleaf48  malehm23  femalecf34_2  femalecf34  femalecm17  ...  \
# 0            NaN       NaN           NaN         NaN         NaN  ...
# 1            NaN       NaN           NaN         NaN         NaN  ...
# 2            NaN       NaN           NaN         NaN         NaN  ...
# 3            2.0       1.0           NaN         1.0         NaN  ...
# 4            NaN       NaN           NaN         NaN         NaN  ...
# ...          ...       ...           ...         ...         ...  ...
# 2602         NaN       NaN           NaN         NaN         NaN  ...
# 2603         NaN       NaN           NaN         NaN         NaN  ...
# 2604         NaN       NaN           NaN         NaN         NaN  ...
# 2605         NaN       NaN           NaN         NaN         NaN  ...
# 2606         NaN       NaN           NaN         NaN         NaN  ...
#
#       AWLRHUE8GWXG4  AX7QB1F1M1IDO  AXKHNWMKGT751  AXMPSUNKUBEIL  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 2602            NaN            NaN            NaN            NaN
# 2603            NaN            NaN            NaN            NaN
# 2604            NaN            NaN            NaN            NaN
# 2605            NaN            NaN            NaN            NaN
# 2606            NaN            NaN            NaN            NaN
#
#       AXMQBHHU22TSP  AY0758IITCGOZ  AY7RI824FORAE  AYBFVMPV70TDP  \
# 0               NaN            NaN            NaN            NaN
# 1               NaN            NaN            NaN            NaN
# 2               NaN            NaN            NaN            NaN
# 3               NaN            NaN            NaN            NaN
# 4               NaN            NaN            NaN            NaN
# ...             ...            ...            ...            ...
# 2602            NaN            NaN            NaN            NaN
# 2603           10.0            NaN            NaN            NaN
# 2604            NaN            NaN            NaN            NaN
# 2605           10.0            NaN            NaN            NaN
# 2606            NaN            NaN            NaN            NaN
#
#       AYDHJW4ZG0D38  AZD9Z5B2U40G2
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 2602            NaN            NaN
# 2603            NaN            NaN
# 2604            NaN            NaN
# 2605            NaN            NaN
# 2606            NaN            NaN
#
# [2607 rows x 363 columns]

# %% [markdown]
# # Drop unnecessary columns

# %%
raw_df.drop(columns=[col for col in raw_df.columns if col not in ['mean', 'image']], inplace=True)
raw_df.rename(columns={'mean': 'label'}, inplace=True)
raw_df
# Out:
#          label                                    image
# 0     1.117647        kuma-kum-GKbPbR0ZAT4-unsplash.jpg
# 1     1.000000             pexels-cottonbro-5529905.jpg
# 2     1.000000         pexels-nishant-aneja-2561432.jpg
# 3     1.428571                   woman-1929550_1920.jpg
# 4     1.500000          pexels-himesh-mehta-3059930.jpg
# ...        ...                                      ...
# 2602  9.000000                pexels-pixabay-247322.jpg
# 2603  9.375000                   women-5930352_1920.jpg
# 2604  9.222222  francesca-zama-1fhl_kmbfAE-unsplash.jpg
# 2605  9.625000           sofia--LNdco1UgNY-unsplash.jpg
# 2606  9.333333          pexels-mart¿¬-pardo-1674318.jpg
#
# [2607 rows x 2 columns]

# %% [markdown]
# # Check for all files

# %%
files = [file for file in os.listdir('MEB_cropped_images')]
files.__len__()
# Out:
# 2396

# %%
raw_df = raw_df[raw_df['image'].isin(files)]
raw_df
# Out:
#          label                                    image
# 0     1.117647        kuma-kum-GKbPbR0ZAT4-unsplash.jpg
# 1     1.000000             pexels-cottonbro-5529905.jpg
# 4     1.500000          pexels-himesh-mehta-3059930.jpg
# 5     1.888889         pexels-kaniseeyapose-2751061.jpg
# 7     2.000000     imad-clicks-2_qmEnz7bQ4-unsplash.jpg
# ...        ...                                      ...
# 2602  9.000000                pexels-pixabay-247322.jpg
# 2603  9.375000                   women-5930352_1920.jpg
# 2604  9.222222  francesca-zama-1fhl_kmbfAE-unsplash.jpg
# 2605  9.625000           sofia--LNdco1UgNY-unsplash.jpg
# 2606  9.333333          pexels-mart¿¬-pardo-1674318.jpg
#
# [2386 rows x 2 columns]

# %% [markdown]
# # Make gender and race columns

# %%
for gender in os.listdir('MEB_images'):
    for race in os.listdir(f'MEB_images/{gender}'):
        for file in os.listdir(f'MEB_images/{gender}/{race}'):
            if file in raw_df['image'].values:
                raw_df.loc[raw_df['image'] == file, 'gender'] = gender
                raw_df.loc[raw_df['image'] == file, 'race'] = race
raw_df
# Out:
# /tmp/ipykernel_10732/3737112613.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_df.loc[raw_df['image'] == file, 'gender'] = gender
# /tmp/ipykernel_10732/3737112613.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   raw_df.loc[raw_df['image'] == file, 'race'] = race
#          label                                    image  gender        race
# 0     1.117647        kuma-kum-GKbPbR0ZAT4-unsplash.jpg  female   caucasian
# 1     1.000000             pexels-cottonbro-5529905.jpg    male       asian
# 4     1.500000          pexels-himesh-mehta-3059930.jpg  female      indian
# 5     1.888889         pexels-kaniseeyapose-2751061.jpg    male       asian
# 7     2.000000     imad-clicks-2_qmEnz7bQ4-unsplash.jpg  female  mideastern
# ...        ...                                      ...     ...         ...
# 2602  9.000000                pexels-pixabay-247322.jpg  female   caucasian
# 2603  9.375000                   women-5930352_1920.jpg  female       asian
# 2604  9.222222  francesca-zama-1fhl_kmbfAE-unsplash.jpg  female    hispanic
# 2605  9.625000           sofia--LNdco1UgNY-unsplash.jpg  female   caucasian
# 2606  9.333333          pexels-mart¿¬-pardo-1674318.jpg    male   caucasian
#
# [2386 rows x 4 columns]

# %% [markdown]
# # Save the cleaned data

# %%
raw_df.to_csv('MEB.csv', index=False)
